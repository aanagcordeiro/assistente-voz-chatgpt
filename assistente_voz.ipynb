# %% [markdown]
# <a href="https://colab.research.google.com/github/aanagcordeiro/assistente-voz-chatgpt/blob/main/assistente_voz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Assistente de voz com chatGPT (simulação)
print ("Assistente iniciado")

entrada = input("fale algo: ")
resposta = f"você disse:  {entrada}"

print("resposta do assistente:", resposta)
# Out:
# Assistente iniciado
